# %% [markdown]
# # RNN

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN

# genrate example data
X = np.random.rand(100, 10, 1)
Y = np.random.randint(0, 2, size=(100,))

# define the model 
model = Sequential()
model.add(SimpleRNN(10, input_shape=(10, 1)))
model.add(Dense(1, activation='sigmoid'))

# compile the model 
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# train the model 
history = model.fit(X, Y, epochs=10, batch_size=32)

# evaluate the model 
loss, accuracy = model.evaluate(X, Y)
print(f"Loss: {loss}, Accuracy: {accuracy}")
# Out:
# Epoch 1/10
# 4/4 [==============================] - 6s 434ms/step - loss: 0.6989 - accuracy: 0.4700
# Epoch 2/10
# 4/4 [==============================] - 0s 44ms/step - loss: 0.6966 - accuracy: 0.4700
# Epoch 3/10
# 4/4 [==============================] - 2s 573ms/step - loss: 0.6945 - accuracy: 0.4700
# Epoch 4/10
# 4/4 [==============================] - 2s 438ms/step - loss: 0.6937 - accuracy: 0.4700
# Epoch 5/10
# 4/4 [==============================] - 1s 184ms/step - loss: 0.6926 - accuracy: 0.4500
# Epoch 6/10
# 4/4 [==============================] - 0s 40ms/step - loss: 0.6915 - accuracy: 0.4700
# Epoch 7/10
# 4/4 [==============================] - 2s 462ms/step - loss: 0.6911 - accuracy: 0.4600
# Epoch 8/10
# 4/4 [==============================] - 2s 461ms/step - loss: 0.6901 - accuracy: 0.4600
# Epoch 9/10
# 4/4 [==============================] - 1s 141ms/step - loss: 0.6898 - accuracy: 0.4600
# Epoch 10/10
# 4/4 [==============================] - 0s 40ms/step - loss: 0.6889 - accuracy: 0.4700
# 4/4 [==============================] - 2s 43ms/step - loss: 0.6886 - accuracy: 0.4700
# Loss: 0.6886411309242249, Accuracy: 0.4699999988079071
