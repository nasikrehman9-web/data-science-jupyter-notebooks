# %% [markdown]
# Stock Market Data scraping in python

# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries 
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns 
import yfinance as yf 
import datetime as dt 
from datetime import date, timedelta 
import plotly.graph_objects as go
import plotly.express as px 

import requests_cache

import requests

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose 
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# DEFINE THE DATES TO FETCH DATA 
today = date.today()
d1 = today.strftime("%Y-%m-%d")
end_date = d1 
d2 = date.today() - timedelta(days=365)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2 
print("Your data will be between these dates: ", start_date, end_date)
# Out:
# Your data will be between these dates:  2025-04-13 2026-04-13

# %%
#define the ticker 
ticker = 'GOLD'


# Set up session with cache and custom User-Agent
session = requests_cache.CachedSession('yfinance.cache')
session.headers['User-Agent'] = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36'

df = yf.download(ticker, session=session, start=start_date, end=end_date, progress=False)
df.head()
# Out:
# 1 Failed download:
# ['GOLD']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Empty DataFrame
# Columns: [(Adj Close, GOLD), (Close, GOLD), (High, GOLD), (Low, GOLD), (Open, GOLD), (Volume, GOLD)]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 0 entries
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, GOOGL)  0 non-null      float64
#  1   (Close, GOOGL)      0 non-null      float64
#  2   (High, GOOGL)       0 non-null      float64
#  3   (Low, GOOGL)        0 non-null      float64
#  4   (Open, GOOGL)       0 non-null      float64
#  5   (Volume, GOOGL)     0 non-null      float64
# dtypes: float64(6)
# memory usage: 0.0 bytes

# %%
df['date'] = df.index
df.reset_index(drop=True, inplace=True)
